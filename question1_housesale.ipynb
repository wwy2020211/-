# %%
class house:
    def __init__(self,squa,price,decorate_choice):
        self.S=squa
        self.price=price
        self.decorate=decorate_choice
    def __next__(self):
        if self.S == 0:
            self.brand = "error"
            return self.S
        else:
            return self.S
    def __iter__(self):
        return self
    def research(self,squ,targetsqu):
        #searchtarget=input("input:")
        for i in range(len(squ)):
            if targetsqu==squ[i].S:
                print("房价：")
                print(salelist[i].price)
                return salelist[i].price
            if i==len(salelist)-1:
                print("找不到相关信息")
                squar=input("输入房屋面积，可取值40，80，100   need square=")
                squar=int(squar)
                dec.research(squ,squar)                
    def addition(self,houselist):                  #self必须加以防报错
        squ=int(input("square:"))
        pr=int(input("price:"))
        c=input("decorate_choice:")
        h=house(squ,pr,c)
        houselist.append(h)
        print("new car:  ")
        print(h.S)
        print(h.price)
    def calculate(self,a,b,c):
        return (a+b+c)
    def update_data(self,houselist):
        t=self.research(updatasqu,houselist)
        if t<=len(carlist):
            print("价格更改为：")
            carlist[t].price=int(input())
            #print("销售量更改为：")
            #carlist[t].salenum=int(input())
class decorate_level0():
    def __init__(self):
        return 
    def __next__(self):
        super().__next__(self)
    def __iter__(self):
        super().__iter__(self)
    def p(self):
        return 5
class decorate_level1():
    def __init__(self):
        return 
    def __next__(self):
        super().__next__(self)
    def __iter__(self):
        super().__iter__(self)
    def p(self):
        return 20
class decorate_level2():
    def __init__(self):
        return 
    def __next__(self):
        super().__next__(self)
    def __iter__(self):
        super().__iter__(self)
    def p(self):
        return 50
class decorate_style0():
    def __init__(self):
        return 
    def __next__(self):
        super().__next__(self)
    def __iter__(self):
        super().__iter__(self)
    def p(self):
        return 20
class decorate_style1():
    def __init__(self):
        return 
    def __next__(self):
        super().__next__(self)
    def __iter__(self):
        super().__iter__(self)
    def p(self):
        return 30
class decorate_style2():
    def __init__(self):
        return 
    def __next__(self):
        super().__next__(self)
    def __iter__(self):
        super().__iter__(self)
    def p(self):
        return 40
class decorate_style3():
    def __init__(self):
        return  
    def __next__(self):
        super().__next__(self)
    def __iter__(self):
        super().__iter__(self)
    def p(self):
        return 60
class decorate(house):
    def __init__(self):
        pass
        #self.choice=super().decorate
    def __next__(self):
        super().__next__(self)
    def __iter__(self):
        super().__iter__(self)
    def decorate_level(self,choice):
        if choice==0:
            pricee=decorate_level0().p()
        elif choice==1:
            pricee=decorate_level1().p()
        elif choice==2:
            pricee=decorate_level2().p()
        else:
            print("at present 没有这种级别")
            deco=input("输入0表示毛胚房，输入1表示简单装修，输入2表示普通装修   need level=")
            deco=int(deco)
            pricee=dec.decorate_level(deco)
        print("decorate_price1=")
        print(pricee)
        return pricee
    def decorate_style(self,choice):                  #self必须加以防报错
        if choice==0:
            prices=decorate_style0().p()
        elif choice==1:
            prices=decorate_style1().p()
        elif choice==2:
            prices=decorate_style2().p()
        elif choice==3:
            prices=decorate_style3().p()
        else:
            print("at present 没有这种风格")
            deco=input("输入0表示毛胚房，输入1表示简单装修，输入2表示普通装修   need style=")
            decor=int(decor)
            prices=dec.decorate_level(decor)
        print("decorate_price2=")
        print(prices)
        return prices
                
if __name__ == "__main__":
    houselist=[40,80,100]              #已有车型列表
    salelist=[]
    dec=decorate()
    print("是否已初始化数据库，否请输入n,是请输入其他")
    flag=input("操作选择：")
    if 1:
        for i in range(len(houselist)):
            if houselist[i]==40:
                p=60
            elif houselist[i]==60:
                p=100
            elif houselist[i]==100:
                p=200
            s=house(houselist[i],p,0)
            salelist.append(s)
    while 1:               #添加车和查找车
        print("add or search(添加车型按a，搜寻按c,更新数据输入e)")
        choice=input("操作选择：")
        if choice=='a':
            salelist[0].addition(salelist)
        elif choice=='c':
            housesqu=input("need square=")
            housesqu=int(housesqu)
            price0=dec.research(salelist,housesqu)
            dec_l=input("输入0表示毛胚房，输入1表示简单装修，输入2表示普通装修   need level=")
            dec_l=int(dec_l)
            price1=dec.decorate_level(dec_l)
            dec_2=input("输入0表示中式，输入1表示日式，输入2表示美式，输入3表示欧式风格 need style=")
            dec_2=int(dec_2)
            price2=dec.decorate_style(dec_2)
            p=dec.calculate(int(price0),int(price1),int(price2))
            print("总花费")
            print(p)
            print("万元")
        elif choice=='e':
            salelist[0].update_data(salelist)
        else:
            break;
# Out:
# 是否已初始化数据库，否请输入n,是请输入其他
# 操作选择：n
# add or search(添加车型按a，搜寻按c,更新数据输入e)
# 操作选择：c
# need square=40
# 房价：
# 60
# 输入0表示毛胚房，输入1表示简单装修，输入2表示普通装修   need level=1
# decorate_price1=
# 20
# 输入0表示中式，输入1表示日式，输入2表示美式，输入3表示欧式风格 need style=2
# decorate_price2=
# 40
# 总花费
# 120
# 万元
# add or search(添加车型按a，搜寻按c,更新数据输入e)
# 操作选择：q
